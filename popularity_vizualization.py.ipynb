# %%
import arrow
import re
import datetime
import argparse
import os
import os.path
import sys
import mysql.connector

from collections import OrderedDict
from contextlib import closing

import arrow
import IPython

import omniture

embed = IPython.embed

sys.path.append("/nykaa/api")
from pas.v2.utils import Utils

import plotly.plotly as py

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
TABLE = 'popularity'
LIMIT = None

# %%
conn = Utils.mysqlConnection()

# %%
arr = [x['views'] for x in Utils.fetchResults(conn, "select * from {table}".format(table=TABLE) )]
print(arr[0:10])
# Out:
# generator: False
# [1, 1, 1, 1, 2, 1, 2, 275, 1, 2]

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
plt.figure(figsize=(50,20))
mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)
print(arr[0:10])
n, bins, patches = plt.hist(arr, 100, normed=1, facecolor='green', alpha=0.75)


plt.xlabel('Popularity')
plt.ylabel('Count')
plt.grid(True)

plt.show()
# Out:
# [1, 1, 1, 1, 2, 1, 2, 275, 1, 2]
